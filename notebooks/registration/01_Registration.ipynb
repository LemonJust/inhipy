# %%
from inhipy.registration.register import run_registration
# %load_ext yamlmagic
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Affine Registration

# %%
# %%yaml reg_config
#
# step: registration
# name: affine_default
#
# data:
#     basedir: /ply/repos/u01/synapse/data/full_pipeline/2023-04-05_15dpf_GAD1b_Full experiment/
#     images:
#         fixed:
#             image_file: Fish2_48_TP2_nonlearner.lsm
#             spacing: [0.23,0.23,0.67] # xyz
#         moving:
#             image_file: Fish2_48_TP1.lsm
#             spacing: [0.23,0.23,0.67] # xyz
#
# parameters:
#   type_of_transform : Affine # SyN
#
# output:
#     basedir: /ply/repos/u01/synapse/data/processed/2023-04-05_15dpf_GAD1b_Full experiment/Fish2_nonlearner/
#     prefix: tp1_to_tp2_affine_

# %%
run_registration(reg_config, verbose = True)
# Out:
# Fixed image:
# ANTsImage (RAI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (1024, 1024, 160)
# 	 Spacing    : (0.23, 0.23, 0.67)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [1. 0. 0. 0. 1. 0. 0. 0. 1.]
#
# Moving image:
# ANTsImage (RAI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (1024, 1024, 160)
# 	 Spacing    : (0.23, 0.23, 0.67)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [1. 0. 0. 0. 1. 0. 0. 0. 1.]
#
# antsRegistration -d 3 -r [0x16f28f00,0x1765f7d0,1] -m mattes[0x16f28f00,0x1765f7d0,1,32,regular,0.2] -t Affine[0.25] -c 2100x1200x1200x10 -s 3x2x1x0 -f 6x4x2x1 -u 1 -z 1 -o [/ply/repos/u01/synapse/data/processed/2023-04-05_15dpf_GAD1b_Full experiment/Fish2_nonlearner/registration/affine_default/tp1_to_tp2_affine_,0x1765f940,0x1765f810] -x [NA,NA] --float 1 --write-composite-transform 0 -v 1
# All_Command_lines_OK
# Using single precision for computations.
# ...

# %% [markdown]
# # SyN Registration Live-Live Demo

# %%
# %%yaml syn_config
#
# step: registration
# name: syn_default
#
# data:
#     basedir: /ply/repos/u01/synapse/data/full_pipeline/2023-04-05_15dpf_GAD1b_Full experiment/
#     images:
#         fixed:
#             image_file: Fish2_48_TP2_nonlearner.lsm
#             spacing: [0.23,0.23,0.67] # xyz
#         moving:
#             image_file: Fish2_48_TP1.lsm
#             spacing: [0.23,0.23,0.67] # xyz, Fixed z : 0.6784644
#
# parameters:
#   type_of_transform : SyN
#
# output:
#     basedir: /ply/repos/u01/synapse/data/processed/2023-04-05_15dpf_GAD1b_Full experiment/Fish2_nonlearner/
#     prefix: tp1_to_tp2_syn_

# %%
run_registration(syn_config, verbose = True)
# Out:
# Fixed image:
# ANTsImage (RAI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (1024, 1024, 160)
# 	 Spacing    : (0.23, 0.23, 0.67)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [1. 0. 0. 0. 1. 0. 0. 0. 1.]
#
# Moving image:
# ANTsImage (RAI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (1024, 1024, 160)
# 	 Spacing    : (0.23, 0.23, 0.67)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [1. 0. 0. 0. 1. 0. 0. 0. 1.]
#
# antsRegistration -d 3 -r [0x177d6f60,0x177dfb90,1] -m mattes[0x177d6f60,0x177dfb90,1,32,regular,0.2] -t Affine[0.25] -c 2100x1200x1200x0 -s 3x2x1x0 -f 4x2x2x1 -x [NA,NA] -m mattes[0x177d6f60,0x177dfb90,1,32] -t SyN[0.200000,3.000000,0.000000] -c [40x20x0,1e-7,8] -s 2x1x0 -f 4x2x1 -u 1 -z 1 -o [/ply/repos/u01/synapse/data/processed/2023-04-05_15dpf_GAD1b_Full experiment/Fish2_nonlearner/registration/syn_default/tp1_to_tp2_syn_,0x177ddb00,0x177df9f0] -x [NA,NA] --float 1 --write-composite-transform 0 -v 1
# ...

# %% [markdown]
# # SyN Registration Live-Fixed Demo

# %%
# %%yaml syn_live_fixed_config
#
# step: registration
# name: syn_fixed_to_live
#
# data:
#     basedir: /ply/repos/u01/synapse/data/full_pipeline/2023-04-05_15dpf_GAD1b_Full experiment/
#     images:
#         fixed:
#             image_file: Fish2_48_TP2_nonlearner.lsm
#             spacing: [0.23,0.23,0.67] # xyz
#         moving:
#             image_file: Fish2-Fixed-561HuC_405DAPI.lsm
#             spacing: [0.23,0.23,0.6784644] # xyz
#             channel: 0
#
# parameters:
#   type_of_transform : SyN
#
# output:
#     basedir: /ply/repos/u01/synapse/data/processed/2023-04-05_15dpf_GAD1b_Full experiment/Fish2_nonlearner/
#     prefix: fixed_to_tp2_syn_

# %%
run_registration(syn_live_fixed_config, verbose = True)
# Out:
# Fixed image:
# ANTsImage (RAI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (1024, 1024, 160)
# 	 Spacing    : (0.23, 0.23, 0.67)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [1. 0. 0. 0. 1. 0. 0. 0. 1.]
#
# Moving image:
# ANTsImage (RAI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (1024, 1024, 160)
# 	 Spacing    : (0.23, 0.23, 0.6785)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [1. 0. 0. 0. 1. 0. 0. 0. 1.]
#
# antsRegistration -d 3 -r [0x16f04190,0x16f5f7e0,1] -m mattes[0x16f04190,0x16f5f7e0,1,32,regular,0.2] -t Affine[0.25] -c 2100x1200x1200x0 -s 3x2x1x0 -f 4x2x2x1 -x [NA,NA] -m mattes[0x16f04190,0x16f5f7e0,1,32] -t SyN[0.200000,3.000000,0.000000] -c [40x20x0,1e-7,8] -s 2x1x0 -f 4x2x1 -u 1 -z 1 -o [/ply/repos/u01/synapse/data/processed/2023-04-05_15dpf_GAD1b_Full experiment/Fish2_nonlearner/registration/syn_fixed_to_live/fixed_to_tp2_syn_,0x16d09b80,0x16f5f800] -x [NA,NA] --float 1 --write-composite-transform 0 -v 1
# ...
